# %% [markdown]
# # Basic Project

# %%
# import pandas as pd
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import mean_squared_error, mean_absolute_error
# import numpy as np

# data = pd.read_csv('/content/student.csv')

# X = data[['Hours']]
# y = data['Score']

# model = LinearRegression()
# model.fit(X, y)

# predicted_score = model.predict(X)

# mae = mean_absolute_error(y, predicted_score)
# mse = mean_squared_error(y, predicted_score)
# rmse = np.sqrt(mse)

# print("Mean Absolute Error (MAE): ", round(mae, 2))
# print("Mean Squared Error (MSE): ", round(mse, 2))
# print("Root Mean Squared Error (RMSE): ", round(rmse, 2))

# new_hour = float(input("Enter an hour: "))
# new_pred = model.predict([[new_hour]])
# print(f"Prediction for {new_hour} hours is score {new_pred}")

# %% [markdown]
# # Advanced Project

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# data = pd.read_csv('/content/student_performance_5000(Sheet1).csv')

# X = data[['Study Hours per Week']]

# y = data['Final Score']

# model = LinearRegression()

# model.fit(X, y)
# predicted_score = model.predict(X)

# mae = mean_absolute_error(y, predicted_score)
# mse = mean_squared_error(y, predicted_score)
# rmse = np.sqrt(mse)
# r2 = r2_score(y, predicted_score)

# print("Mean Absolute Error (MAE): ", round(mae, 2))
# print("Mean Squared Error (MSE): ", round(mse, 2))
# print("Root Mean Squared Error (RMSE): ", round(rmse, 2))
# print("R^2 Score (Model Accuracy): ", round(r2, 4))

# #Graphs
# plt.figure(figsize= (10, 6))
# plt.hist(data["Final Score"], bins=30, color='skyblue', edgecolor='black')
# plt.xlabel('Final Score')
# plt.ylabel('No. Of Students')
# plt.title('Distribution of Final Scores')
# plt.grid(True)
# plt.show()

# plt.figure(figsize= (10, 6))
# plt.scatter(X, y, color='mediumpurple', label='Actual Scores')
# plt.plot(X, predicted_score, color='red', label="Predicted Scores (Regression Line)")
# plt.xlabel('Final Score')
# plt.ylabel('Final output')
# plt.title('Model Prediction VS Actual Score')
# plt.grid(True)
# plt.show()

# new_hours = 9.5
# predicted_new_score = model.predict([[new_hours]])
# print(f"Predicted score for {new_hours} hours of study: {predicted_new_score}")
